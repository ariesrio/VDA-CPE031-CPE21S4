# %% [markdown]
# <a href="https://colab.research.google.com/github/ariesrio/VDA-CPE031-CPE21S4/blob/main/EXERCISE_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install pandas

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

slope, intercept = np.polyfit(x,y,1)
y_pred = slope * x + intercept

plt.scatter(x,y)
plt.plot(x,y_pred,color='red')
plt.show()

# %%
x = np.linspace(-2,2,100)
y = x ** 2
fig = plt.figure(figsize=(10,5))
plt.plot(x,y)
plt.show()

# %%
x = np.array([60,90,70,85,80,65,75,60,75,70])
y = np.array([70,95,70,75,90,75,75,60,80,65])

slope, intercept = np.polyfit(x,y,1)

y_pred = slope * x + intercept

plt.scatter(x,y)
plt.plot(x,y_pred,color='red')
plt.show()
