# %% [markdown]
# <a href="https://colab.research.google.com/github/ariesrio/VDA-CPE031-CPE21S4/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

import pandas as pd
data = {
    'apples':[3,2,0,1],
    'oranges':[0,3,7,2]
}
purchases = pd.DataFrame(data)
print(purchases)
# Out:
# ...
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.to_csv('fruits.csv')
files.download('fruits.csv')

# %%
purchases.to_excel('fruits.xlsx')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9db1f611-5ca1-4889-ad97-22937253a3c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9db1f611-5ca1-4889-ad97-22937253a3c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('fruits.csv')
data
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data.head(3)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7

# %%
data.tail(3)
# Out:
#   Unnamed: 0  apples  oranges
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %% [markdown]
# # Laboratory Manual Activity

# %%
#1
from google.colab import drive
import pandas as pd

# Mounting your Google Drive
drive.mount('/content/drive')

# Loading CSV from your Drive
csv_path = '/content/dataset.csv'
df = pd.read_csv(csv_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#2
df = pd.DataFrame(df)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#3
import pandas as pd
data_dict = {
    'Person ID': [1, 2, 3, 4, 5],
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male'],
    'Age': [27, 28, 28, 28, 28],
    'Occupation': ['Software Engineer', 'Doctor', 'Doctor', 'Sales Representative', 'Sales Representative'],
    'Sleep Duration': [6.1, 6.2, 6.2, 5.9, 5.9],
    'Quality of Sleep': [6, 6, 6, 4, 4],
    'Physical Activity Level': [42, 60, 60, 30, 30],
    'Stress Level': [6, 8, 8, 8, 8],
    'BMI Category': ['Overweight', 'Normal', 'Normal', 'Obese', 'Obese'],
    'Blood Pressure': ['126/83', '125/80', '125/80', '140/90', '140/90'],
    'Heart Rate': [77, 75, 75, 85, 85],
    'Daily Steps': [4200, 10000, 10000, 3000, 3000],
    'Sleep Disorder': ['None', 'None', 'None', 'Sleep Apnea', 'Sleep Apnea']
}

df_dict = pd.DataFrame(data_dict)

df = pd.DataFrame(df)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#4
data_list_of_dicts = [
    {'Person ID': 1, 'Gender': 'Male', 'Age': 27, 'Occupation': 'Software Engineer', 'Sleep Duration': 6.1,
     'Quality of Sleep': 6, 'Physical Activity Level': 42, 'Stress Level': 6, 'BMI Category': 'Overweight',
     'Blood Pressure': '126/83', 'Heart Rate': 77, 'Daily Steps': 4200, 'Sleep Disorder': 'None'},

    {'Person ID': 2, 'Gender': 'Male', 'Age': 28, 'Occupation': 'Doctor', 'Sleep Duration': 6.2,
     'Quality of Sleep': 6, 'Physical Activity Level': 60, 'Stress Level': 8, 'BMI Category': 'Normal',
     'Blood Pressure': '125/80', 'Heart Rate': 75, 'Daily Steps': 10000, 'Sleep Disorder': 'None'},

    {'Person ID': 3, 'Gender': 'Male', 'Age': 28, 'Occupation': 'Doctor', 'Sleep Duration': 6.2,
     'Quality of Sleep': 6, 'Physical Activity Level': 60, 'Stress Level': 8, 'BMI Category': 'Normal',
     'Blood Pressure': '125/80', 'Heart Rate': 75, 'Daily Steps': 10000, 'Sleep Disorder': 'None'},

    {'Person ID': 4, 'Gender': 'Male', 'Age': 28, 'Occupation': 'Sales Representative', 'Sleep Duration': 5.9,
     'Quality of Sleep': 4, 'Physical Activity Level': 30, 'Stress Level': 8, 'BMI Category': 'Obese',
     'Blood Pressure': '140/90', 'Heart Rate': 85, 'Daily Steps': 3000, 'Sleep Disorder': 'Sleep Apnea'},

    {'Person ID': 5, 'Gender': 'Male', 'Age': 28, 'Occupation': 'Sales Representative', 'Sleep Duration': 5.9,
     'Quality of Sleep': 4, 'Physical Activity Level': 30, 'Stress Level': 8, 'BMI Category': 'Obese',
     'Blood Pressure': '140/90', 'Heart Rate': 85, 'Daily Steps': 3000, 'Sleep Disorder': 'Sleep Apnea'},
]

df_list_of_dicts = pd.DataFrame(data_list_of_dicts)

df = pd.DataFrame(df)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#5
# Selecting a single column
single_column = df_dict['Gender']
print("Single column - Gender:")
single_column
# Out:
# Single column - Gender:
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# Name: Gender, dtype: object

# %%
# Selecting multiple columns
multiple_columns = df_dict[['Occupation', 'Sleep Duration', 'Stress Level']]
print("\nMultiple columns - Occupation, Sleep Duration, Stress Level:")
multiple_columns
# Out:
# Multiple columns - Occupation, Sleep Duration, Stress Level:
#              Occupation  Sleep Duration  Stress Level
# 0     Software Engineer             6.1             6
# 1                Doctor             6.2             8
# 2                Doctor             6.2             8
# 3  Sales Representative             5.9             8
# 4  Sales Representative             5.9             8

# %%
# Selecting a single row using .iloc[]
single_row_iloc = df_dict.iloc[2]  # Selects the third row (index 2)
print("\nSingle row selected using .iloc[]:")
single_row_iloc
# Out:
# Single row selected using .iloc[]:
# Person ID                       3
# Gender                       Male
# Age                            28
# Occupation                 Doctor
# Sleep Duration                6.2
# Quality of Sleep                6
# Physical Activity Level        60
# Stress Level                    8
# BMI Category               Normal
# Blood Pressure             125/80
# Heart Rate                     75
# Daily Steps                 10000
# Sleep Disorder               None
# Name: 2, dtype: object

# %%
# Selecting multiple rows using .iloc[]
multiple_rows_iloc = df_dict.iloc[[1, 3]]  # Selects the second and fourth rows (indices 1 and 3)
print("\nMultiple rows selected using .iloc[]:")
multiple_rows_iloc
# Out:
# Multiple rows selected using .iloc[]:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 1          2   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 1                 6                       60             8       Normal
# 3                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 1         125/80          75        10000           None
# 3         140/90          85         3000    Sleep Apnea
